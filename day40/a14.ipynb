# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('sales_data.csv')
print(df.head())
# Out:
#          date   product  sales_amount
# 0  2023-01-01  Widget A           100
# 1  2023-01-02  Widget B           150
# 2  2023-01-03  Widget A           200
# 3  2023-01-04  Widget C           120
# 4  2023-01-05  Widget B           180

# %%
total_sales = df['sales_amount'].sum()

# %%
print(f"total Sales: ${total_sales}")
# Out:
# total Sales: $1730

# %%
product_sales = df.groupby('product')['sales_amount'].sum().reset_index()

# %%
print(product_sales)
# Out:
#     product  sales_amount
# 0  Widget A           850
# 1  Widget B           490
# 2  Widget C           390

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.set_index('date',inplace=True)
df['sales_amount'].plot()
plt.title('Sales Over Time')
plt.show()
